# %% [markdown]
# # LIBRARIES

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %% [markdown]
# # LOAD DATA

# %%
# Load data from CSV file
data = pd.read_csv('iris.csv')

# Extract features
X = data[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]

# %% [markdown]
# # KMEANS MODEL

# %%
# Encode the species labels
label_encoder = LabelEncoder()
data['Species'] = label_encoder.fit_transform(data['Species'])

# Fit k-means clustering model
kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(X)

# Get cluster labels
cluster_labels = kmeans.labels_

# Plotting the clusters
plt.figure(figsize=(8, 6))
plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=cluster_labels, cmap='viridis', s=50, alpha=0.7)
plt.title('K-Means Clustering')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.colorbar()
plt.show()
# Out:
# c:\Users\heman\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
